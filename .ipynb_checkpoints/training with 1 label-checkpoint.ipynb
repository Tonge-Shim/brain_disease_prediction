# %% [markdown]
# - densenet/resnet-inception/inceptionv4 apply
# -  resnet/inceptions: with smaller parameters

# %%
import os
from glob import glob
import numpy as np
import nibabel as nib
import torch
import pandas as pd
from torch import nn
from torch import optim
from torch.utils.data import TensorDataset, DataLoader, Dataset
from torch.autograd import Variable
from torchvision import transforms
import torch.nn as nn
from sklearn.metrics import roc_auc_score, average_precision_score
import tqdm
from operator import add
import matplotlib.pyplot as plt
import easydict

# %%
import wandb

# !wandb login
# Out:
# wandb: Currently logged in as: tonge (use `wandb login --relogin` to force relogin)

# %%
# os.getcwd()
# !pwd
# Out:
# /home/chaeeun/Desktop/brain disease prediction

# %%
data = np.load('./sliced_datas/sliced_436.npy')
# 747: 메모리 에러

# %%
label_1 = np.load('./labels/label_1.npy')
type(label_1)
# Out:
# numpy.ndarray

# %%
X_train = data[:621]
X_test = data[621:]
# y_train = norm_label[:621]
# y_test = norm_label[621:]
y_train = label_1[:621]
y_test = label_1[621:]

# %%
datadict = {
    'X_train': X_train, 
    'y_train' : y_train,
    'X_test': X_test,
    'y_test': y_test
}

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
class mridataset(Dataset):
    def __init__(self, data, data_type):
        if data_type == 'train':
            self.X = data['X_train']
            self.y = data['y_train']
        elif data_type == 'test':
            self.X = data['X_test']
            self.y = data['y_test']
            
        assert len(self.X) == len(self.y), "length should be same between input and label"
        
        self.X = torch.FloatTensor(self.X)#cpu tensor
        self.y = torch.FloatTensor(self.y)#cpu tensor
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        X = self.X[index]
        y = self.y[index]
        return {
            'X': X,
            'y_target': y
        }

# %% [markdown]
# # MODELS

# %%
# import torchvision.models as models
# r3d_18 = models.video.r3d_18(pretrained=True, )
# print(r3d_18)

# %% [markdown]
# # parameter change

# %%
# # r3d_18.parameters change
# r3d_18.fc = nn.Linear(in_features = 512, out_features = 5, bias = True)
# r3d_18.stem[0] = nn.Conv3d(1, 64, kernel_size = (3, 7, 7), stride = (1, 2, 2), padding = (1, 3, 3), bias = True)

# %%
#results
# r3d_18.parameters

# %%
# model = r3d_18
# model.to(device)

# %% [markdown]
# ## densenet

# %%
#densenet
#from model.densenet import densenet
#model = densenet(121)
#model.to(device)

# %% [markdown]
# ## resnet

# %%
# #resnet
from model.resnet import *
model =  generate_model(50, n_classes=1)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv3d(2048, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )

# %% [markdown]
# ## inception_resnet_v2

# %%
from model.inception_resnet_v2 import Inception_ResNetv2
model = Inception_ResNetv2(classes = 1)
model.to(device)
# Out:
# Inception_ResNetv2(
#   (features): Sequential(
#     (0): Stem(
#       (features): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (4): Conv3d(
#           (conv): Conv3d(64, 80, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(80, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (branch_0): Conv3d(
#         (conv): Conv3d(192, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(192, 48, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(192, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(192, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (1): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (2): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (3): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (4): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (5): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (6): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (7): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (8): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (9): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (10): Inception_ResNet_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(32, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(48, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(128, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (11): Reduction_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(320, 384, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(320, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(256, 384, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (12): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (13): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (14): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (15): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (16): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (17): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (18): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (19): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (20): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (21): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (22): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (23): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (24): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (25): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (26): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (27): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (28): Inception_ResNet_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1088, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1088, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(128, 149, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(149, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(149, 170, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(170, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(170, 192, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(384, 1088, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (29): Inception_ResNet_B(
# ...
#           (conv): Conv3d(256, 288, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(288, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (33): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (34): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (35): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (36): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (37): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (38): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (39): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (40): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (41): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (42): Inception_ResNet_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(2080, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (conv): Conv3d(448, 2080, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (conv): Conv3d(
#     (conv): Conv3d(2080, 1536, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (bn): BatchNorm3d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (global_average_pooling): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (linear): Linear(in_features=1536, out_features=1, bias=True)
# )

# %% [markdown]
# ## inceptionv4

# %%
from model.inceptionv4 import Inceptionv4
model = Inceptionv4(classes=1)
model.to(device)
# Out:
# Inceptionv4(
#   (features): Sequential(
#     (0): Stem(
#       (conv3d_1a_3x3x3): Conv3d(
#         (conv): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv3d_2a_3x3x3): Conv3d(
#         (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv3d_2b_3x3x3): Conv3d(
#         (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (mixed_3a_branch_0): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (mixed_3a_branch_1): Conv3d(
#         (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (mixed_4a_branch_0): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(160, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (mixed_4a_branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(160, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 64, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(64, 64, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(64, 64, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (mixed_5a_branch_0): Conv3d(
#         (conv): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#         (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (mixed_5a_branch_1): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Inception_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (brance_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (2): Inception_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (brance_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (3): Inception_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (brance_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (4): Inception_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(64, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (brance_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(384, 96, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (5): Reduction_A(
#       (branch_0): Conv3d(
#         (conv): Conv3d(384, 384, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(384, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 224, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(224, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (7): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (8): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (9): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (10): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (11): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (12): Inception_B(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1024, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 213, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(213, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(213, 234, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(234, 256, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 202, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(202, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(202, 212, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(212, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(212, 224, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(224, 234, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(234, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Conv3d(
#           (conv): Conv3d(234, 244, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(244, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Conv3d(
#           (conv): Conv3d(244, 256, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1024, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (13): Reduction_B(
#       (branch_0): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_1): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1024, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(256, 277, kernel_size=(1, 1, 7), stride=(1, 1, 1), padding=(0, 0, 3), bias=False)
#           (bn): BatchNorm3d(277, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(277, 298, kernel_size=(1, 7, 1), stride=(1, 1, 1), padding=(0, 3, 0), bias=False)
#           (bn): BatchNorm3d(298, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(298, 320, kernel_size=(7, 1, 1), stride=(1, 1, 1), padding=(3, 0, 0), bias=False)
#           (bn): BatchNorm3d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Conv3d(
#           (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), bias=False)
#           (bn): BatchNorm3d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2): MaxPool3d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (14): Inception_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Conv3d(
#         (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_1): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_2): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_3): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(384, 426, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(426, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(426, 468, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(468, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(468, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2_1): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_2): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_3): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (15): Inception_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Conv3d(
#         (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_1): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_2): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_3): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(384, 426, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(426, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(426, 468, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(468, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(468, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2_1): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_2): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_3): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (16): Inception_C(
#       (branch_0): Conv3d(
#         (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1): Conv3d(
#         (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_1): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_2): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_1_3): Conv3d(
#         (conv): Conv3d(384, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2): Sequential(
#         (0): Conv3d(
#           (conv): Conv3d(1536, 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (1): Conv3d(
#           (conv): Conv3d(384, 426, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#           (bn): BatchNorm3d(426, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Conv3d(
#           (conv): Conv3d(426, 468, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#           (bn): BatchNorm3d(468, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Conv3d(
#           (conv): Conv3d(468, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#           (bn): BatchNorm3d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (branch_2_1): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 1, 3), stride=(1, 1, 1), padding=(0, 0, 1), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_2): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(1, 3, 1), stride=(1, 1, 1), padding=(0, 1, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_2_3): Conv3d(
#         (conv): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (branch_3): Sequential(
#         (0): AvgPool3d(kernel_size=3, stride=1, padding=1)
#         (1): Conv3d(
#           (conv): Conv3d(1536, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (global_average_pooling): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (linear): Linear(in_features=2048, out_features=1, bias=True)
# )

# %% [markdown]
# # config dictionary

# %%
config = easydict.EasyDict({'n_epoch': 20,
                           'batch_size':8,
                           'lr': 0.001,
                           'save_dir':'./',
                           'dropout' : 0.2, 
                            'modelname' : 'resnet34',
                            'dataname' : 'sliced_436'
                           })

# %%
train_loader = DataLoader(mridataset(datadict, data_type = 'train'), batch_size = config.batch_size, num_workers = 8, shuffle = True)
#num_workers: cpu 여러개로 학습을 시켜라(8)
test_loader = DataLoader(mridataset(datadict, data_type = 'test'), batch_size = config.batch_size, num_workers = 8, shuffle = False)

# %%
# #save&load path
# filename = f'Model_{config.modelname}_batch_{config.batch_size}_lr_{config.lr}'
# output_path = os.path.join(config.save_dir, filename)
# print('Model will be saved in {}'.format(output_path))

# %% [markdown]
# RMSProp with decay of 0.9 and epsilon(e//what is this??)= 1.0.  We used a learning rate of 0.045, decayed every two epochs using an exponential rate of 0.94.  --> decay every 2 epochs??using an exponential rate of 0.94===>lr.scheduler??

# %%
#Loss
criterion = nn.MSELoss()
criterion2 = nn.L1Loss()
#optimizer#
optimizer = torch.optim.Adam(model.parameters(), lr = config.lr)#this was for resnet
#optimizer = torch.optim.RMSprop(model.parameters(), lr = config.lr)#, weight_decay = 0.9, momentum = 0.9)#for inception resnet

# %%
#trainer
wandb.init(project=config.modelname +'_'+ config.dataname + '_' + str(config.n_epoch), config = config)
wandb.watch(model, log='all')

start = torch.cuda.Event(enable_timing = True)
end = torch.cuda.Event(enable_timing = True)

start.record()
loss_plot, val_loss_plot = [], []
maeloss_plot, maeval_loss_plot = [], []
y_each_maeloss_plot = []
for n_epoch in range(1, config.n_epoch + 1):
    print(f'Train Epoch {n_epoch} start!')
    avg_train_loss = 0
    avg_train_mae = 0
    
    model.train()
    
    for iter, batch in enumerate(train_loader):
        X = batch['X'].to(device)
        y_target = batch['y_target'].to(device)
        optimizer.zero_grad()#optimizer reset
        
        y_pred = model(X)
        loss = criterion(y_pred, y_target)
        loss2 = criterion2(y_pred, y_target)


        loss.backward()
        optimizer.step()
        avg_train_loss += loss.item() / len(train_loader)
        avg_train_mae += loss2.item() / len(train_loader)

        
        
    print('[Train] loss: {:.3f}'.format(avg_train_loss))
    print('[Train] mae_loss: {:.3f}'.format(avg_train_mae))
    loss_plot.append(avg_train_loss)
    maeloss_plot.append(avg_train_mae)

    # wandb.log({'Train mse Loss' : avg_train_loss, 'Train mae Loss': avg_train_mae})#0, 2, 4, ...
    

        #evaluation
    model.eval()
    avg_test_loss = 0
    avg_test_mae = 0
        
    with torch.no_grad(): #no need to compute gradient
#         y_each_maeloss = [0, 0, 0, 0, 0]
        y_predicted = []
        for iter, batch in enumerate(test_loader):
            X = batch['X'].to(device)
            y_target = batch['y_target'].to(device)

            y_pred = model(X)

    
            if n_epoch == config.n_epoch:
                y_predicted.append(y_pred)


            loss = criterion(y_pred, y_target)
            loss2 = criterion2(y_pred, y_target)

            avg_test_loss += loss.item()/len(test_loader)
            avg_test_mae += loss2.item()/len(test_loader)

        print('[Test]  loss: {:.3f}'.format(avg_test_loss))
        print('[Test]  mae_loss: {:.3f}'.format(avg_test_mae))
#         print('[Test, y_each_maeloss]: ',y_each_maeloss)
        print('\n')
        val_loss_plot.append(avg_test_loss)
        maeval_loss_plot.append(avg_test_mae)
#         y_each_maeloss_plot.append(y_each_maeloss)
        wandb.log({'Train mse Loss' : avg_train_loss, 'Train mae Loss': avg_train_mae, 'Test mse Loss': avg_test_loss, 'Test mae Loss': avg_test_mae})
    
    
end.record()
torch.cuda.synchronize()
print(start.elapsed_time(end), "ms")

# wandb.finish()
y_predicted_concat = torch.cat([*y_predicted], dim = 0)

y1_p = y_predicted_concat.reshape(100,1).cpu()
# y2_p = y_predicted_concat[:, 1].reshape(100,1).cpu()

#정답치
y1 = label_1[621:].reshape(100,1)
# y2 = unnorm_label[621:, 1].reshape(100,1)


one = np.hstack((y1_p, y1))
# two = np.hstack((y2_p, y2))


scat_1 = [[x, y] for (x, y) in one]#zip(one[:,0], one[:,1])
# scat_2 = [[x, y] for (x, y) in two]#zip(one[:,0], one[:,1])


table_1 = wandb.Table(data = scat_1, columns = ['predicted', 'truth'])
scatter_1 = wandb.plot.scatter(table_1, x = 'predicted', y = 'target', title = 'scat_1')

# table_2 = wandb.Table(data = scat_2, columns = ['predicted', 'truth'])
# scatter_2 = wandb.plot.scatter(table_2, x = 'predicted', y = 'target', title = 'scat_2')


wandb.log({ 'scatter_1': scatter_1})

wandb.finish()
# Out:
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">volcanic-yogurt-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tonge/resnet34_sliced_436_20" target="_blank">https://wandb.ai/tonge/resnet34_sliced_436_20</a><br/>
#                 Run page: <a href="https://wandb.ai/tonge/resnet34_sliced_436_20/runs/1drd96bw" target="_blank">https://wandb.ai/tonge/resnet34_sliced_436_20/runs/1drd96bw</a><br/>
#                 Run data is saved locally in <code>/home/chaeeun/Desktop/brain disease prediction/wandb/run-20211103_111443-1drd96bw</code><br/><br/>
# Train Epoch 1 start!
# [Train] loss: 0.638
# [Train] mae_loss: 0.282
# [Test]  loss: 0.009
# [Test]  mae_loss: 0.083
#
#
# Train Epoch 2 start!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-e0a52ffc7db6> in <module>
#      28
#      29         loss.backward()
# ---> 30         optimizer.step()
#      31         avg_train_loss += loss.item() / len(train_loader)
#      32         avg_train_mae += loss2.item() / len(train_loader)
#
# ~/.conda/envs/sce/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/.conda/envs/sce/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/.conda/envs/sce/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     116                    lr=group['lr'],
#     117                    weight_decay=group['weight_decay'],
# --> 118                    eps=group['eps'])
#     119         return loss
#
# ~/.conda/envs/sce/lib/python3.7/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
# y_predicted_concat = torch.cat([*y_predicted], dim = 0)

# %%
# run = wandb.init(project = config.modelname +'_'+ config.dataname + '_' + str(config.n_epoch), config = config)

artifact = wandb.Artifact('model', type='model')
# artifact.add_file('model.pth')

wandb.log_artifact(artifact)
wandb.join()
# Out:
# <br/>Waiting for W&B process to finish, PID 10231<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/chaeeun/Desktop/brain disease prediction/wandb/run-20211013_165156-2bgz80y3/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/chaeeun/Desktop/brain disease prediction/wandb/run-20211013_165156-2bgz80y3/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Train mse Loss</td><td>0.79483</td></tr><tr><td>Train mae Loss</td><td>0.66267</td></tr><tr><td>Test mse Loss</td><td>3.75818</td></tr><tr><td>Test mae Loss</td><td>1.3394</td></tr><tr><td>_runtime</td><td>165</td></tr><tr><td>_timestamp</td><td>1634111681</td></tr><tr><td>_step</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Train mse Loss</td><td>█▆▄▂▄▂▂▁▃▁</td></tr><tr><td>Train mae Loss</td><td>█▇▄▂▃▃▄▁▂▃</td></tr><tr><td>Test mse Loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Test mae Loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>_timestamp</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>_step</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">rare-lake-3</strong>: <a href="https://wandb.ai/tonge/densenet_sliced_2_10/runs/2bgz80y3" target="_blank">https://wandb.ai/tonge/densenet_sliced_2_10/runs/2bgz80y3</a><br/>

# %%
#mse
plt.plot(loss_plot[1:], label='train_loss')
plt.plot(val_loss_plot[1:], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss(mse)')
plt.legend()
plt.show()

# %%
#mae
plt.plot(maeloss_plot[1:], label='train_loss')
plt.plot(maeval_loss_plot[1:], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss(mae)')
plt.legend()
plt.show()

# %%
x = np.arange(-0.05, 0.25, 0.05)
plt.plot(x,x)
plt.title("y1", fontsize = 15)
plt.scatter( one[:,0], one[:, 1], color = 'blue', alpha = .5)
# plt.scatter(n_1[:,0], n_1[:,1], color = 'red', alpha = .5)
plt.grid()
plt.show()

# x = np.arange(30, 38, 1)
# plt.plot(x, x)
# plt.title("y2", fontsize = 15)
# plt.scatter( two[:,0], two[:, 1], color = 'blue', alpha = .5)
# plt.grid()
# plt.show()
